# %% [markdown]
# Python (15%):
# Stworzyć listę 10 elementową z parami losowych liczb naturalnych od 1 d0 10. Cel: [(x1,y1),(x2,y2),...]

# %%
import random
lista=[]
for i in range(10):
    lista.append(random.sample(range(1,11),2
                              ))
    
print(lista)
# Out:
# [[9, 4], [5, 4], [3, 10], [3, 2], [7, 4], [5, 3], [7, 8], [1, 9], [3, 7], [6, 10]]

# %% [markdown]
# Napisać funkcję która po otrzymaniu powyższej listy par stworzy listę z taką samą ilością elementów które będą potęgą: pierwszy element pary będzie podstawą a drugi element wykładnikiem. Cel: [x1^y1, x2^y2,...]

# %%
potegowanie=[[x**y]for [x,y] in lista]
print(potegowanie)
# Out:
# [[6561], [625], [59049], [9], [2401], [125], [5764801], [1], [2187], [60466176]]

# %% [markdown]
# Pandas (15%):
# Stworzyć data frame który będzie miał pierwsze elementy z par zadania powyżej jako pierwszą kolumnę, a drugi element z pary jako drugą kolumnę. Cel:

# %%
import pandas as pd
import numpy as np
ramkadanych = pd.DataFrame(data=lista)
print(ramkadanych)
# Out:
#    0   1
# 0  9   4
# 1  5   4
# 2  3  10
# 3  3   2
# 4  7   4
# 5  5   3
# 6  7   8
# 7  1   9
# 8  3   7
# 9  6  10

# %% [markdown]
# Dodać trzecią kolumnę która będzie potęgą tak jak w zadaniu 1. Uwaga: kolumna ta powinna być wyliczona z kolumny drugiej i trzeciej, a nie wzięta z listy z zadania 1.

# %%
ramkadanych['potega']=ramkadanych[0]**ramkadanych[1]
print(ramkadanych)
# Out:
#    0   1    potega
# 0  9   4      6561
# 1  5   4       625
# 2  3  10     59049
# 3  3   2         9
# 4  7   4      2401
# 5  5   3       125
# 6  7   8   5764801
# 7  1   9         1
# 8  3   7      2187
# 9  6  10  60466176

# %% [markdown]
# Klasyfikacja (30%):
# Zbiór danych: https://archive.ics.uci.edu/ml/datasets/wine
# Jeden z algorytmów: decision tree, regresja logistyczna
# Użyć pętli dla przetestowania różnych wybranych parametrów
# Użyć cv

# %%
train_wine = pd.read_csv("wine_data.csv",names=["Klasa", "Alcohol", "Malic_acid","Ash","Alcalinity_of_ash","Magnesium","Total_phenols","Flavanoids","Nonflavanoid_phenols","Proanthocyanins","Color_intensity","Hue","OD280_OD315_of_diluted wines","Proline"])

# %%
#df=pd.DataFrame(train_wine)

# %%
train_wine.keys()
# Out:
# Index(['Klasa', 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_of_ash',
#        'Magnesium', 'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols',
#        'Proanthocyanins', 'Color_intensity', 'Hue',
#        'OD280_OD315_of_diluted wines', 'Proline'],
#       dtype='object')

# %%
np.nan_to_num(train_wine)
# Out:
# array([[1.000e+00, 1.423e+01, 1.710e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.000e+00, 1.320e+01, 1.780e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.000e+00, 1.316e+01, 2.360e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [3.000e+00, 1.327e+01, 4.280e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [3.000e+00, 1.317e+01, 2.590e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [3.000e+00, 1.413e+01, 4.100e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
train_wine.isnull().values.sum()
# Out:
# 0

# %%
train_wine.isnull().any().any()
# Out:
# False

# %%
#np.isfinite(mat.all())

# %%
#train_wine.typeof()

# %%
train_wine.head()
# Out:
#    Klasa  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280_OD315_of_diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
X = pd.DataFrame(data=train_wine, columns = train_wine[["Alcohol","Malic_acid","Ash","Alcalinity_of_ash","Magnesium","Total_phenols","Flavanoids","Nonflavanoid_phenols","Proanthocyanins","Color_intensity","Hue","OD280_OD315_of_diluted wines","Proline"]])
y = pd.Series(train_wine[["Klasa"]])

#X = pd.DataFrame(train_w_white[["fixed acidity","volatile acidity","citric acid","citric acid","density","sulphates"]])
#y = pd.Series(train_w_white["quality"])

# %%
X.keys()
# Out:
# Float64Index([            [14.23, 1.71, 2.43, 15.6, 127.0, 2.8, 3.06, 0.28, 2.29, 5.64, 1.04, 3.92, 1065.0],
#                            [13.2, 1.78, 2.14, 11.2, 100.0, 2.65, 2.76, 0.26, 1.28, 4.38, 1.05, 3.4, 1050.0],
#                            [13.16, 2.36, 2.67, 18.6, 101.0, 2.8, 3.24, 0.3, 2.81, 5.68, 1.03, 3.17, 1185.0],
#                            [14.37, 1.95, 2.5, 16.8, 113.0, 3.85, 3.49, 0.24, 2.18, 7.8, 0.86, 3.45, 1480.0],
#                            [13.24, 2.59, 2.87, 21.0, 118.0, 2.8, 2.69, 0.39, 1.82, 4.32, 1.04, 2.93, 735.0],
#                           [14.2, 1.76, 2.45, 15.2, 112.0, 3.27, 3.39, 0.34, 1.97, 6.75, 1.05, 2.85, 1450.0],
#                             [14.39, 1.87, 2.45, 14.6, 96.0, 2.5, 2.52, 0.3, 1.98, 5.25, 1.02, 3.58, 1290.0],
#                           [14.06, 2.15, 2.61, 17.6, 121.0, 2.6, 2.51, 0.31, 1.25, 5.05, 1.06, 3.58, 1295.0],
#                             [14.83, 1.64, 2.17, 14.0, 97.0, 2.8, 2.98, 0.29, 1.98, 5.2, 1.08, 2.85, 1045.0],
# ...

# %%
X.astype(np.float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/isa/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/envs/isa/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ...

# %%
X = X.as_matrix().astype(np.float32)
y = y.as_matrix().astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-bb56fd576e05> in <module>()
#       1 X = X.as_matrix().astype(np.float32)
# ----> 2 y = y.as_matrix().astype(np.float32)
#
# ValueError: setting an array element with a sequence.

# %%
from sklearn.model_selection import train_test_split #dzielnie na zetsawy
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import cross_val_score # ogólna funkcja do CV
from sklearn.model_selection import StratifiedKFold # podział na zbiory do CV

# %%
best_score = np.inf
parameters = {}

# %%
#train_wine = train_wine.reset_index()

# %%
#for depth in range (1,11):
    #classifier = DecisionTreeClassifier(criterion = "entropy", max_depth = depth)
    #scores = cross_val_score(classifier, X_train, y_train, cv = skf)
    #results.append(scores.mean())
    #print("Accuracy: {} (std {})".format(scores.mean(), scores.std()))



for depth in range (1,11):
    for min_split in range(2,21):
        for min_leaf in range(1,21):
            for criterion in ["gini", "entropy"]:
                classifier = DecisionTreeClassifier(max_depth = depth,
                                                  min_samples_split = min_split,
                                                  min_samples_leaf = min_leaf,
                                                  criterion=criterion)
                scores = cross_val_score(classifier, X_train, y_train, cv = 5)
                print("MSE: {} (std {})".format(scores.mean(), scores.std()))
                if scores.mean() < 0:
                    pass
                elif scores.mean() < best_score:
                    print("New best parameters!")
                    parameters["best_depth"] = depth
                    parameters["best_min_split"] = min_split
                    parameters["best_min_leaf"] = min_leaf
                    best_score = scores.mean()

# %%
for depth in range (1,11):
#for depth in trange (1,11):
    for min_split in range(2,21):
        for min_leaf in range(1,21):
            for criterion in ["gini", "entropy"]:
                clf = DecisionTreeClassifier(max_depth = depth, min_samples_split = min_split, 
                                             min_samples_leaf = min_leaf, criterion = criterion)
                scores = cross_val_score(clf, X_train, y_train, cv = 5)
                if scores.mean() > best_score:
                    #print("New best parameters!")
                    parameters["best_depth"] = depth
                    parameters["best_min_split"] = min_split
                    parameters["best_min_leaf"] = min_leaf
                    parameters["best_criterion"] = criterion
                    best_score = scores.mean()
                    print("Accuracy: {}".format(scores.mean()))
                    print("max_depth: {}, min_samples_split: {}, min_samples_leaf: {}, criterion: {}".format(depth, 
                                                                                                             min_split, 
                                                                                                             min_leaf, 
                                                                                                             criterion))

# %%
parameters

# %%
regressor = DecisionTreeClassifier(max_depth = parameters["best_depth"],
                                  min_samples_split = parameters["best_min_split"],
                                  min_samples_leaf = parameters["best_min_leaf"])

# %%
regressor.fit(X = X_test, y = y_test)

# %%
regressor.predict(X = X_test, y = y_test)

# %%
regressor.predict(X_test, check_input=True)

# %% [markdown]
# Regresja (30%)
# Zbiór danych: https://archive.ics.uci.edu/ml/datasets/Wine+Quality - białe wino
# Jeden z algorytmów: decision tree, regresja logistyczna
# Użyć pętli dla przetestowania różnych wybranych parametrów
# Użyć cv

# %%
train_w_white = pd.read_csv("winequality-white.csv", header=0, sep=";")

# %%
train_w_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
train_w_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# %%
#X = pd.DataFrame(train_w_white["fixed acidity", "volatile acidity", "citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"])
#y = pd.Series(train_w_white["quality"])

X = pd.DataFrame(train_w_white[["fixed acidity","volatile acidity","citric acid","citric acid","density","sulphates"]])
y = pd.Series(train_w_white["quality"])


#X = pd.DataFrame(train_w_white["density"])
#y = pd.Series(train_w_white["quality"])

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  citric acid  density  \
# 0            7.0              0.27         0.36         0.36   1.0010
# 1            6.3              0.30         0.34         0.34   0.9940
# 2            8.1              0.28         0.40         0.40   0.9951
# 3            7.2              0.23         0.32         0.32   0.9956
# 4            7.2              0.23         0.32         0.32   0.9956
#
#    sulphates
# 0       0.45
# 1       0.49
# 2       0.44
# 3       0.40
# 4       0.40

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.33, random_state=42)

# %%
import numpy as np
best_score = np.inf
parameters = {}

# %%
for depth in range (1,11):
    for min_split in range(2,21):
        for min_leaf in range(1,21):
            regressor = DecisionTreeRegressor(max_depth = depth,
                                              min_samples_split = min_split,
                                              min_samples_leaf = min_leaf)
            scores = cross_val_score(regressor, X, y, cv = 5)
            print("MSE: {} (std {})".format(scores.mean(), scores.std()))
            if scores.mean() < 0:
                pass
            elif scores.mean() < best_score:
                print("New best parameters!")
                parameters["best_depth"] = depth
                parameters["best_min_split"] = min_split
                parameters["best_min_leaf"] = min_leaf
                best_score = scores.mean()
# Out:
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# New best parameters!
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# MSE: 0.08834118039086288 (std 0.02342823018625325)
# ...

# %%
parameters
# Out:
# {'best_depth': 8, 'best_min_split': 14, 'best_min_leaf': 3}

# %%
regressor = DecisionTreeRegressor(max_depth = parameters["best_depth"],
                                  min_samples_split = parameters["best_min_split"],
                                  min_samples_leaf = parameters["best_min_leaf"])

# %%
regressor.fit(X = X, y = y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=8, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=3,
#            min_samples_split=14, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
prediction_regressor = regressor.predict(X_test)

# %%
results = pd.DataFrame({"y_true":y_test, "y_dtc":prediction_regressor})

# %%
results
# Out:
#          y_dtc  y_true
# 4656  5.966746       7
# 3659  6.559880       8
# 907   6.352550       8
# 4352  5.840000       5
# 3271  7.444444       7
# 4632  5.966746       6
# 2244  5.122222       5
# 1924  5.966746       4
# 3801  5.384615       6
# 2634  5.367816       5
# 2827  6.352550       7
# 79    4.777778       5
# 350   7.750000       7
# 1370  5.966746       6
# 4480  5.285714       5
# 3783  5.367816       5
# 2890  6.559880       8
# 3193  5.840000       5
# 1281  6.352550       7
# 4388  5.708661       6
# 653   5.708661       6
# 2290  6.066194       7
# 4101  5.467532       5
# 1921  5.513514       5
# 598   5.708661       8
# 2067  5.966746       5
# 2794  5.367816       5
# 3826  6.295775       6
# 841   6.750000       7
# 2643  4.000000       5
# ...        ...     ...
# 1593  5.891304       6
# 121   5.708661       5
# 1721  5.891304       7
# 2287  5.122222       5
# 3519  5.840000       7
# 910   5.122222       5
# 124   6.066194       6
# 4442  5.451613       5
# ...
